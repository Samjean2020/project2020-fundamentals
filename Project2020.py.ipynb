# %% [markdown]
# #  Project 2020
# ## Fundamentals of Data Analysis¶
# ## Due: last commit on or before January 8th, 2021

# %% [markdown]
# #### This is my solution to the Project assessment. The author is Jean Bonsenge (G00387887@gmit.ie).¶

# %% [markdown]
# ### Instructions
# In this project you must perform and explain simple linear regression using Python
# on the powerproduction dataset available on Moodle. The goal is to accurately predict
# wind turbine power output from wind speed values using the data set as a basis.
# Your submission must be in the form of a git repository containing, at a minimum, the
# following items:
# 1. Jupyter notebook that performs simple linear regression on the data set.
# 2. In that notebook, an explanation of your regression and an analysis of its accuracy.
# 3. Standard items in a git repository such as a README.
# To enhance your submission, you might consider comparing simple linear regression to
# other types of regression on this data set. Rest assured, all the above concepts will be
# explored in lecture videos and other materials in the coming semester.

# %% [markdown]
# ### Introduction

# %% [markdown]
# This is my solution to the Project assessment. The author is Jean Bonsenge (G00387887@gmit.ie).

# %% [markdown]
# ### References

# %% [markdown]
#  [1] PennState(2020) "Lesson 2: Simple Linear Regression (SLR) Model":https://online.stat.psu.edu/stat462/node/91/(Accessed 01/12/2020)
#  [2] Yale (1997-98) “Multiple Linear Regression (yale.edu): http://www.stat.yale.edu/Courses/1997-98/101/linmult.htm( Accessed 01/12/2020)

# %% [markdown]
# ### Development

# %% [markdown]
# #### Defining Simple Linear Regression

# %% [markdown]
# Simple linear regression can be defined as a statistical technique that enables us to sump up and investigate corelations between two variables. Variable on the x-axis is called the predicator, explanatory or independent; whereas, the variable on the y-axis is considered as the response, outcome or dependent[1]
#
# Multiple linear regression has vocation to model the correlations between two or additional explanatory variables and a dependent variable by fitting a linear equation to experimental data [2]

# %%
# Draw a simple linear regression using sklearn and seaborn regression plot functions. 
from sklearn.linear_model import LinearRegression
sns.regplot (df["speed"], df ["power"], color = 'b')
plt.show()

# %% [markdown]
# #### About Dataset

# %% [markdown]
#  The powerproduction dataset is available on Moodle.

# %% [markdown]
# #### Import Python relevant modules

# %%
# Magic command in Ipython displaying the output.  
# %matplotlib inline

# Numercial arrays and fitting lines
import numpy as np
# Plots.
import matplotlib.pyplot as plt
# Data visualisation
import seaborn as sns
# Nicer plot style.
plt.style.use('ggplot')
# Bigger plots.
plt.rcParams['figure.figsize'] = 20, 10

#Import pandas as pd for data analysis and manipulation.
import pandas as pd

# %% [markdown]
# #### Loading dataset

# %%
# Pandas DataFrame() function to read the csv file.
df = pd.read_csv("powerproduction.csv")

# %%
df
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
# Get a summary of dataset
df.describe()
# Out:
#             speed       power
# count  500.000000  500.000000
# mean    12.590398   48.014584
# std      7.224991   41.614572
# min      0.000000    0.000000
# 25%      6.324750    5.288000
# 50%     12.550500   41.645500
# 75%     18.775250   93.537000
# max     25.000000  113.556000

# %%
# Output the five first rows and two variables of dataset.
df.head()
# Out:
#    speed  power
# 0  0.000    0.0
# 1  0.125    0.0
# 2  0.150    0.0
# 3  0.225    0.0
# 4  0.275    0.0

# %%
# Output the last five rows and two variables of dataset.
df.tail()
# Out:
#       speed  power
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0

# %% [markdown]
# #### Performing and definingSimple Linear Regression on powerproducntion dataset

# %%
# Draw a simple linear regression using sklearn and seaborn regression plot functions. 
from sklearn.linear_model import LinearRegression
sns.regplot (df["power"], df ["speed"], color = 'r')
plt.show()

# %% [markdown]
# #### Predicting wind turbine power output from wind speed values

# %% [markdown]
# #### Regression explanation and analyis

# %% [markdown]
# #### Comparison between simple linear regression and multiple linear regression
